# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.model_selection import train_test_split
from glob import glob

import os
import shutil

# %%
# !unzip -q "/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/images.zip" -d "/content/drive/MyDrive/IITP_졸음운전/data_zip_sep"
# !unzip -q "/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/labels.zip" -d "/content/drive/MyDrive/IITP_졸음운전/data_zip_sep"

# %%
# %cd /content/drive/MyDrive/IITP_졸음운전/data_zip_sep
# Out:
# /content/drive/.shortcut-targets-by-id/1m8RYxpHLPj320yDPfTg1abSb0kFSqO1G/IITP_졸음운전/data_zip_sep

# %%
# %ls
# Out:
# images/  images.zip  labels/  labels.zip

# %%
os.mkdir('train')
os.mkdir('train/images')
os.mkdir('train/labels')

os.mkdir('test')
os.mkdir('test/images')
os.mkdir('test/labels')

os.mkdir('valid')
os.mkdir('valid/images')
os.mkdir('valid/labels')

# %%
img_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/images/*.jpg')
lab_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/labels/*.txt')

print(len(img_list), len(lab_list))
# Out:
# 29917 16695

# %%
train_img_list, test_img_list = train_test_split(img_list, test_size=0.3)

print(len(train_img_list), len(test_img_list))
# Out:
# 20941 8976

# %%
test_img_list, valid_img_list = train_test_split(test_img_list, test_size=0.3)

print(len(test_img_list), len(valid_img_list))
# Out:
# 6283 2693

# %%
train_img = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/train/images'
test_img = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/test/images'
valid_img = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/valid/images'

train_lab = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/train/labels'
test_lab = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/test/labels'
valid_lab = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/valid/labels'

# %%
img_dir = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/images'
lab_dir = '/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/labels'

for fname in train_img_list :
    fname = fname.split('/')[-1]
    shutil.move(img_dir + '/' + fname, train_img + '/' + fname)
    fname = os.path.splitext(fname)[0]
    shutil.move(lab_dir + '/' + fname + '.txt', train_lab + '/' + fname + '.txt')

for fname in test_img_list :
    fname = fname.split('/')[-1]
    shutil.move(img_dir + '/' + fname, test_img + '/' + fname)
    fname = os.path.splitext(fname)[0]
    shutil.move(lab_dir + '/' + fname + '.txt', test_lab + '/' + fname + '.txt')

for fname in valid_img_list :
    fname = fname.split('/')[-1]
    shutil.move(img_dir + '/' + fname, valid_img + '/' + fname)
    fname = os.path.splitext(fname)[0]
    shutil.move(lab_dir + '/' + fname + '.txt', valid_lab + '/' + fname + '.txt')

# %%
train_img_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/train/images/*.jpg')
test_img_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/test/images/*.jpg')
valid_img_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/valid/images/*.jpg')
train_lab_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/train/labels/*.txt')
test_lab_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/test/labels/*.txt')
valid_lab_list = glob('/content/drive/MyDrive/IITP_졸음운전/data_zip_sep/valid/labels/*.txt')

print('num of images:', len(train_img_list), len(test_img_list), len(valid_img_list))
print('num of labels:', len(train_lab_list), len(test_lab_list), len(valid_lab_list))
# Out:
# num of images: 0 0 0
# num of labels: 0 0 0
