# %%
# %cd /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/
# Out:
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN

# %%
# !unzip -qq /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset.zip

# %% [markdown]
# # CNN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Setting

# %% [markdown]
#  - 경로 설정

# %%
import os

base_dir = '/content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset'

train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
val_dir = os.path.join(base_dir, 'val')

print(train_dir)
print(test_dir)
print(val_dir)
# Out:
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/train
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/test
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/val

# %% [markdown]
#  - train 경로 설정

# %%
train_normal_dir = os.path.join(train_dir, 'normal')
train_search_dir = os.path.join(train_dir, 'search')
train_phone_dir = os.path.join(train_dir, 'phone')
train_drowsy_dir = os.path.join(train_dir, 'drowsy')

print(train_normal_dir)
print(train_search_dir)
print(train_phone_dir)
print(train_drowsy_dir)
# Out:
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/train/normal
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/train/search
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/train/phone
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/train/drowsy

# %% [markdown]
#  - val 경로 설정

# %%
val_normal_dir = os.path.join(val_dir, 'normal')
val_search_dir = os.path.join(val_dir, 'search')
val_phone_dir = os.path.join(val_dir, 'phone')
val_drowsy_dir = os.path.join(val_dir, 'drowsy')

print(val_normal_dir)
print(val_search_dir)
print(val_phone_dir)
print(val_drowsy_dir)
# Out:
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/val/normal
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/val/search
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/val/phone
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/val/drowsy

# %% [markdown]
#  - test 경로 설정

# %%
test_normal_dir = os.path.join(test_dir, 'normal')
test_search_dir = os.path.join(test_dir, 'search')
test_phone_dir = os.path.join(test_dir, 'phone')
test_drowsy_dir = os.path.join(test_dir, 'drowsy')

print(test_normal_dir)
print(test_search_dir)
print(test_phone_dir)
print(test_drowsy_dir)
# Out:
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/test/normal
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/test/search
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/test/phone
# /content/drive/MyDrive/본프로젝트_천대원/졸음운전/CNN/dataset/test/drowsy

# %% [markdown]
# - Return the train images as a list

# %%
train_normal_fnames = os.listdir(train_normal_dir)
train_search_fnames = os.listdir(train_search_dir)
train_phone_fnames = os.listdir(train_phone_dir)
train_drowsy_fnames = os.listdir(train_drowsy_dir)

print("Normal:", len(train_normal_fnames))
print("Search:", len(train_search_fnames))
print("Phone:", len(train_phone_fnames))
print("Drowsy:", len(train_drowsy_fnames))
# Out:
# Normal: 12800
# Search: 12800
# Phone: 12800
# Drowsy: 12800

# %% [markdown]
# - Return the val images as a list

# %%
val_normal_fnames = os.listdir(val_normal_dir)
val_search_fnames = os.listdir(val_search_dir)
val_phone_fnames = os.listdir(val_phone_dir)
val_drowsy_fnames = os.listdir(val_drowsy_dir)

print("Normal:", len(val_normal_fnames))
print("Search:", len(val_search_fnames))
print("Phone:", len(val_phone_fnames))
print("Drowsy:", len(val_drowsy_fnames))
# Out:
# Normal: 1600
# Search: 1600
# Phone: 1600
# Drowsy: 1600

# %% [markdown]
# - Return the test images as a list

# %%
test_normal_fnames = os.listdir(test_normal_dir)
test_search_fnames = os.listdir(test_search_dir)
test_phone_fnames = os.listdir(test_phone_dir)
test_drowsy_fnames = os.listdir(test_drowsy_dir)

print("Normal:", len(test_normal_fnames))
print("Search:", len(test_search_fnames))
print("Phone:", len(test_phone_fnames))
print("Drowsy:", len(test_drowsy_fnames))
# Out:
# Normal: 1600
# Search: 1600
# Phone: 1600
# Drowsy: 1600

# %% [markdown]
# - Images Rescaling

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 이미지 픽셀을 0 ~ 1 사이의 값으로 스케일 조정
train_dategen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)
validation_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_dategen.flow_from_directory(train_dir,
                                                    batch_size = 16,
                                                    target_size = (128, 128),
                                                    class_mode = 'sparse')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                    batch_size = 16,
                                                    target_size = (128, 128),
                                                    class_mode = 'sparse')

validation_generator = validation_datagen.flow_from_directory(val_dir,
                                                    batch_size = 16,
                                                    target_size = (128, 128),
                                                    class_mode = 'sparse')
# Out:
# Found 51200 images belonging to 4 classes.
# Found 6400 images belonging to 4 classes.
# Found 6400 images belonging to 4 classes.

# %%
# 클래스 확인
train_generator.class_indices
# Out:
# {'drowsy': 0, 'normal': 1, 'phone': 2, 'search': 3}

# %% [markdown]
# #  Model Configuration

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# ResNet-50 모델 불러오기 (include_top=False로 fully-connected layer 제외)
resnet_model = ResNet50(weights='imagenet',
                        include_top=False,
                        input_shape=(128, 128, 3))

# 새로운 Sequential 모델 정의하기
model = Sequential()

# 불러온 ResNet-50 모델을 새로운 Sequential 모델에 추가
model.add(resnet_model)

# 추가적인 레이어 정의
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(4, activation='softmax'))

# ResNet-50 부분은 학습되지 않도록 설정
for layer in resnet_model.layers:
    layer.trainable = False

# EarlyStopping 콜백 정의
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=10,
                               restore_best_weights=True)

# 모델 컴파일
model.compile(
    optimizer= Adam(lr=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 모델 구조 출력
model.summary()
# Out:
# ...
# 94765736/94765736 [==============================] - 1s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# ...
# Total params: 31977604 (121.98 MB)
# Trainable params: 8389892 (32.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %% [markdown]
#  - 모델 학습

# %%
history = model.fit(train_generator,
                    epochs = 200,
                    batch_size = 16,
                    validation_data = validation_generator,
                    callbacks= [early_stopping])
# Out:
# Epoch 1/200
# 3200/3200 [==============================] - 434s 132ms/step - loss: 1.0482 - accuracy: 0.5256 - val_loss: 0.8872 - val_accuracy: 0.6198
# Epoch 2/200
# 3200/3200 [==============================] - 253s 79ms/step - loss: 0.9540 - accuracy: 0.5715 - val_loss: 0.8746 - val_accuracy: 0.6170
# Epoch 3/200
# 3200/3200 [==============================] - 247s 77ms/step - loss: 0.9147 - accuracy: 0.5878 - val_loss: 0.7995 - val_accuracy: 0.6538
# Epoch 4/200
# 3200/3200 [==============================] - 250s 78ms/step - loss: 0.8912 - accuracy: 0.5962 - val_loss: 0.7731 - val_accuracy: 0.6583
# Epoch 5/200
# 3200/3200 [==============================] - 261s 82ms/step - loss: 0.8754 - accuracy: 0.6021 - val_loss: 0.7366 - val_accuracy: 0.6950
# Epoch 6/200
# 3200/3200 [==============================] - 252s 79ms/step - loss: 0.8657 - accuracy: 0.6059 - val_loss: 0.7744 - val_accuracy: 0.6648
# Epoch 7/200
# ...

# %% [markdown]
#  - 학습과정 그려보기

# %%
import matplotlib.pyplot as plt

his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['accuracy']
val_acc = his_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %% [markdown]
#  - 모델 테스트

# %%
import numpy as np
from google.colab import files
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
# 클래스 이름 목록
class_names = ['normal', 'search', 'phone', 'drowsy']

def pred(fname):
    # 이미지 로드 및 전처리
    img = image.load_img(fname, target_size=(128, 128))
    plt.imshow(img)
    plt.axis('off')  # 축을 숨깁니다.
    plt.show()

    x = image.img_to_array(img) / 255.0
    images = np.expand_dims(x, axis=0)

    # 예측
    classes = model.predict(images, batch_size=10)
    print(classes[0])

    # 가장 높은 확률을 가진 클래스의 인덱스를 찾음
    predicted_class_index = np.argmax(classes[0])

    # 해당 인덱스의 클래스 이름 출력
    predicted_class_name = class_names[predicted_class_index]
    print(f"{fname.split('/')[-1]} 사진은 {predicted_class_name}입니다.")

# %%
pred('/content/drowsy1.jpg')
# Out:
# 1/1 [==============================] - 5s 5s/step
# [0.37987643 0.3680376  0.00840066 0.24368522]
# drowsy1.jpg 사진은 normal입니다.

# %%
pred('/content/drowsy2.jpg')
# Out:
# 1/1 [==============================] - 0s 91ms/step
# [9.8054874e-01 4.1287034e-03 9.7942609e-07 1.5321673e-02]
# drowsy2.jpg 사진은 normal입니다.

# %%
pred('/content/noraml1.jpg')
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [2.4693082e-01 7.4778742e-01 5.1981624e-06 5.2766069e-03]
# noraml1.jpg 사진은 search입니다.

# %%
pred('/content/noraml2.jpg')
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [2.1035467e-01 7.8487301e-01 8.2898905e-06 4.7640693e-03]
# noraml2.jpg 사진은 search입니다.

# %%
pred('/content/phone1.jpg')
# Out:
# 1/1 [==============================] - 0s 39ms/step
# [4.3362388e-01 2.5156734e-05 2.1805506e-02 5.4454547e-01]
# phone1.jpg 사진은 drowsy입니다.

# %%
pred('/content/phone2.jpg')
# Out:
# 1/1 [==============================] - 0s 46ms/step
# [0.22638918 0.11848485 0.43552473 0.2196012 ]
# phone2.jpg 사진은 phone입니다.

# %%
pred('/content/search1.jpg')
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [8.0458065e-03 3.6598505e-03 6.1116261e-05 9.8823327e-01]
# search1.jpg 사진은 drowsy입니다.

# %%
pred('/content/search2.jpg')
# Out:
# 1/1 [==============================] - 0s 50ms/step
# [4.9663961e-02 4.1660459e-07 9.4939079e-03 9.4084173e-01]
# search2.jpg 사진은 drowsy입니다.
